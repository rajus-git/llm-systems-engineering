# %% [markdown]
# PEP 8 is Python's official style guide

# %%
# Variables and functions — snake_case
my_name = "Raju"
def calculate_total():
    pass

# Constants — ALL_CAPS
MAX_SIZE = 100
PI = 3.14159

# Classes — PascalCase
class StudentRecord:
    pass

# %% [markdown]
# Each import on its own line
#
#     import os
#     import sys           # ✅
#
# import os, sys       # ❌
#
# # Order: standard library → third party → your own files
# import os            # 1. standard library
# import numpy as np   # 2. third party
# import my_utils      # 3. your own code

# %% [markdown]
# #### Comment
# # Single line comment — space after #
# x = 10  # inline comment — 2 spaces before #
#
# # ❌ bad comment — states the obvious
# x = x + 1  # add 1 to x
#
# # ✅ good comment — explains WHY
# x = x + 1  # offset by 1 to account for zero-based index
